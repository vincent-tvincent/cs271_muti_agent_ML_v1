# %%
import time

from SwarmEnvironment import *
from SwarmAgent import *
import numpy
# ------------------------------
# 4. Training Loop
# ------------------------------
numpy.random.seed(20)
manual_selected_device = "cuda"

n_agents = 20
visible_neighbor_amount = 3
env = SwarmEnv(n_agents=n_agents, space_size=50, linear_displacement=1.0, visible_neighbor_amount=visible_neighbor_amount)
env.set_random_goals()
agent = Agent(state_dim=env.observation_dimension, action_dim=env.action_amount, device=manual_selected_device)
print(env.action_amount)
agent.gamma = 0.95 # q learning gamma, learning rate
agent.epsilon = 1.0 # action randomness 1 for fully random
agent.batch_size = 64

epsilon_decay = 0.99 # action randomness decay rate
epsilon_min = 0.05 # minimum epsilon

env.goal_reward = 50.0
env.collision_reward = -10.0
env.distance_reward_factor = 5.0 # how much nearest neighbor evey agent can visit

training_steps = 1000
episodes_length = 500

for episode in range(training_steps):
    observations = env.reset()
    total_reward = 0

    for step in range(episodes_length):
       # Batched GPU/MPS inference for all agents
       actions = agent.select_multiple_actions(observations)  # replaces the for-loop

        # Environment step (expects actions as a list or array)
       next_observations, rewards, done, _ = env.step(actions)

       # Store transitions for all agents
       for i in range(env.n_agents):
           agent.store(observations[i], actions[i], rewards[i], next_observations[i])

       # Train DQN
       agent.train_step()

       # Move to next step
       observations = next_observations
       total_reward += np.mean(rewards)

       # End early if environment finishes
       if done:
           break



    
    agent.update_target()
    agent.epsilon = max(epsilon_min, agent.epsilon * epsilon_decay)
    print(f"Episode {episode}, average total reward {total_reward:.2f}, eps {agent.epsilon:.2f}")
# Out:
# using device :  cuda
# 1440
# /home/blue-lobster/PycharmProjects/cs271_muti_agent_ML_v1/SwarmAgent.py:91: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:253.)
#   s = torch.tensor(s, dtype=torch.float32, device=self.device)
# Episode 0, average total reward -44.02, eps 0.99
# Episode 1, average total reward -37.16, eps 0.98
# Episode 2, average total reward -32.06, eps 0.97
# Episode 3, average total reward -38.13, eps 0.96
# Episode 4, average total reward -163.69, eps 0.95
# Episode 5, average total reward -35.64, eps 0.94
# Episode 6, average total reward -497.12, eps 0.93
# Episode 7, average total reward -27.87, eps 0.92
# Episode 8, average total reward -24.30, eps 0.91
# Episode 9, average total reward -29.33, eps 0.90
# Episode 10, average total reward -35.91, eps 0.90
# Episode 11, average total reward -29.20, eps 0.89
# Episode 12, average total reward -483.30, eps 0.88
# Episode 13, average total reward -36.01, eps 0.87
# Episode 14, average total reward -39.22, eps 0.86
# Episode 15, average total reward -43.74, eps 0.85
# Episode 16, average total reward -57.89, eps 0.84
# Episode 17, average total reward -489.23, eps 0.83
# Episode 18, average total reward -33.90, eps 0.83
# Episode 19, average total reward -46.25, eps 0.82
# Episode 20, average total reward -49.55, eps 0.81
# Episode 21, average total reward -45.03, eps 0.80
# Episode 22, average total reward -105.67, eps 0.79
# Episode 23, average total reward -43.58, eps 0.79
# Episode 24, average total reward -219.31, eps 0.78
# Episode 25, average total reward -403.28, eps 0.77
# Episode 26, average total reward -59.94, eps 0.76
# Episode 27, average total reward -580.55, eps 0.75
# Episode 28, average total reward -619.97, eps 0.75
# Episode 29, average total reward -444.01, eps 0.74
# Episode 30, average total reward -100.80, eps 0.73
# Episode 31, average total reward -573.49, eps 0.72
# Episode 32, average total reward -259.60, eps 0.72
# Episode 33, average total reward -212.28, eps 0.71
# Episode 34, average total reward -155.81, eps 0.70
# Episode 35, average total reward -108.63, eps 0.70
# Episode 36, average total reward -108.87, eps 0.69
# Episode 37, average total reward -48.16, eps 0.68
# Episode 38, average total reward -117.34, eps 0.68
# Episode 39, average total reward -16.28, eps 0.67
# Episode 40, average total reward -215.22, eps 0.66
# Episode 41, average total reward -22.79, eps 0.66
# Episode 42, average total reward -103.59, eps 0.65
# Episode 43, average total reward -21.42, eps 0.64
# Episode 44, average total reward -18.14, eps 0.64
# Episode 45, average total reward -124.50, eps 0.63
# Episode 46, average total reward -179.82, eps 0.62
# Episode 47, average total reward -26.20, eps 0.62
# Episode 48, average total reward -31.58, eps 0.61
# Episode 49, average total reward -15.73, eps 0.61
# Episode 50, average total reward -26.50, eps 0.60
# Episode 51, average total reward -155.27, eps 0.59
# Episode 52, average total reward -153.05, eps 0.59
# Episode 53, average total reward -24.68, eps 0.58
# Episode 54, average total reward -6.07, eps 0.58
# Episode 55, average total reward -18.62, eps 0.57
# Episode 56, average total reward -132.50, eps 0.56
# Episode 57, average total reward -134.70, eps 0.56
# Episode 58, average total reward -55.15, eps 0.55
# Episode 59, average total reward -34.52, eps 0.55
# Episode 60, average total reward -29.15, eps 0.54
# Episode 61, average total reward -26.26, eps 0.54
# Episode 62, average total reward -451.06, eps 0.53
# Episode 63, average total reward -232.05, eps 0.53
# Episode 64, average total reward -21.77, eps 0.52
# Episode 65, average total reward -24.43, eps 0.52
# Episode 66, average total reward -29.84, eps 0.51
# Episode 67, average total reward -7.19, eps 0.50
# Episode 68, average total reward -12.32, eps 0.50
# Episode 69, average total reward -17.25, eps 0.49
# Episode 70, average total reward -10.85, eps 0.49
# Episode 71, average total reward 1.11, eps 0.48
# Episode 72, average total reward -24.41, eps 0.48
# Episode 73, average total reward 6.19, eps 0.48
# Episode 74, average total reward 14.99, eps 0.47
# Episode 75, average total reward -12.36, eps 0.47
# Episode 76, average total reward -10.88, eps 0.46
# Episode 77, average total reward -61.48, eps 0.46
# Episode 78, average total reward 3.53, eps 0.45
# Episode 79, average total reward 0.23, eps 0.45
# Episode 80, average total reward 20.75, eps 0.44
# Episode 81, average total reward 9.63, eps 0.44
# Episode 82, average total reward 6.80, eps 0.43
# Episode 83, average total reward -193.05, eps 0.43
# Episode 84, average total reward 12.44, eps 0.43
# Episode 85, average total reward 16.63, eps 0.42
# Episode 86, average total reward -1.52, eps 0.42
# Episode 87, average total reward -0.62, eps 0.41
# Episode 88, average total reward 5.62, eps 0.41
# Episode 89, average total reward 6.68, eps 0.40
# Episode 90, average total reward 20.10, eps 0.40
# Episode 91, average total reward -3.00, eps 0.40
# Episode 92, average total reward 4.72, eps 0.39
# Episode 93, average total reward 6.82, eps 0.39
# Episode 94, average total reward -0.64, eps 0.38
# Episode 95, average total reward 17.89, eps 0.38
# Episode 96, average total reward 19.01, eps 0.38
# Episode 97, average total reward 2.58, eps 0.37
# Episode 98, average total reward 14.67, eps 0.37
# Episode 99, average total reward 24.01, eps 0.37
# Episode 100, average total reward 20.47, eps 0.36
# Episode 101, average total reward 14.88, eps 0.36
# Episode 102, average total reward 36.49, eps 0.36
# Episode 103, average total reward 15.24, eps 0.35
# Episode 104, average total reward 15.78, eps 0.35
# Episode 105, average total reward 32.75, eps 0.34
# Episode 106, average total reward 32.49, eps 0.34
# Episode 107, average total reward 18.27, eps 0.34
# Episode 108, average total reward 14.43, eps 0.33
# Episode 109, average total reward 20.17, eps 0.33
# Episode 110, average total reward 14.34, eps 0.33
# Episode 111, average total reward 16.67, eps 0.32
# Episode 112, average total reward 17.85, eps 0.32
# Episode 113, average total reward 29.12, eps 0.32
# Episode 114, average total reward 40.40, eps 0.31
# Episode 115, average total reward 31.68, eps 0.31
# Episode 116, average total reward 21.69, eps 0.31
# Episode 117, average total reward 47.19, eps 0.31
# Episode 118, average total reward 22.66, eps 0.30
# Episode 119, average total reward 27.09, eps 0.30
# Episode 120, average total reward 35.93, eps 0.30
# Episode 121, average total reward 45.08, eps 0.29
# Episode 122, average total reward 47.97, eps 0.29
# Episode 123, average total reward 75.04, eps 0.29
# Episode 124, average total reward 18.53, eps 0.28
# Episode 125, average total reward 50.72, eps 0.28
# Episode 126, average total reward 61.07, eps 0.28
# Episode 127, average total reward 34.04, eps 0.28
# Episode 128, average total reward 43.20, eps 0.27
# Episode 129, average total reward 54.00, eps 0.27
# Episode 130, average total reward 64.48, eps 0.27
# Episode 131, average total reward 20.84, eps 0.27
# Episode 132, average total reward 69.35, eps 0.26
# Episode 133, average total reward 74.42, eps 0.26
# Episode 134, average total reward 47.54, eps 0.26
# Episode 135, average total reward 70.34, eps 0.25
# Episode 136, average total reward 67.85, eps 0.25
# Episode 137, average total reward 68.05, eps 0.25
# Episode 138, average total reward 68.58, eps 0.25
# Episode 139, average total reward 53.97, eps 0.24
# Episode 140, average total reward 68.80, eps 0.24
# Episode 141, average total reward 77.26, eps 0.24
# Episode 142, average total reward 56.68, eps 0.24
# Episode 143, average total reward 77.25, eps 0.24
# Episode 144, average total reward 58.31, eps 0.23
# Episode 145, average total reward 70.66, eps 0.23
# Episode 146, average total reward 65.25, eps 0.23
# Episode 147, average total reward 65.82, eps 0.23
# Episode 148, average total reward 79.63, eps 0.22
# Episode 149, average total reward 69.88, eps 0.22
# Episode 150, average total reward 87.24, eps 0.22
# Episode 151, average total reward 70.84, eps 0.22
# Episode 152, average total reward 55.55, eps 0.21
# Episode 153, average total reward 74.13, eps 0.21
# Episode 154, average total reward 68.35, eps 0.21
# Episode 155, average total reward 70.05, eps 0.21
# Episode 156, average total reward 61.18, eps 0.21
# Episode 157, average total reward 67.73, eps 0.20
# Episode 158, average total reward 73.12, eps 0.20
# Episode 159, average total reward 67.35, eps 0.20
# Episode 160, average total reward 60.67, eps 0.20
# Episode 161, average total reward 76.98, eps 0.20
# Episode 162, average total reward 67.98, eps 0.19
# Episode 163, average total reward 70.66, eps 0.19
# Episode 164, average total reward 81.33, eps 0.19
# Episode 165, average total reward 64.69, eps 0.19
# Episode 166, average total reward 68.73, eps 0.19
# Episode 167, average total reward 65.93, eps 0.18
# Episode 168, average total reward 62.94, eps 0.18
# Episode 169, average total reward 77.30, eps 0.18
# Episode 170, average total reward 61.56, eps 0.18
# Episode 171, average total reward 63.57, eps 0.18
# Episode 172, average total reward 77.58, eps 0.18
# Episode 173, average total reward 57.95, eps 0.17
# Episode 174, average total reward 70.68, eps 0.17
# Episode 175, average total reward 75.98, eps 0.17
# Episode 176, average total reward 68.32, eps 0.17
# Episode 177, average total reward 64.12, eps 0.17
# Episode 178, average total reward 60.59, eps 0.17
# Episode 179, average total reward 80.15, eps 0.16
# Episode 180, average total reward 69.44, eps 0.16
# Episode 181, average total reward 64.78, eps 0.16
# Episode 182, average total reward 83.36, eps 0.16
# Episode 183, average total reward 85.15, eps 0.16
# Episode 184, average total reward 76.37, eps 0.16
# Episode 185, average total reward 75.63, eps 0.15
# Episode 186, average total reward 76.60, eps 0.15
# Episode 187, average total reward 69.01, eps 0.15
# Episode 188, average total reward 71.90, eps 0.15
# Episode 189, average total reward 64.94, eps 0.15
# Episode 190, average total reward 74.01, eps 0.15
# Episode 191, average total reward 65.89, eps 0.15
# Episode 192, average total reward 82.39, eps 0.14
# Episode 193, average total reward 64.27, eps 0.14
# Episode 194, average total reward 82.98, eps 0.14
# Episode 195, average total reward 84.20, eps 0.14
# Episode 196, average total reward 84.05, eps 0.14
# Episode 197, average total reward 139.76, eps 0.14
# Episode 198, average total reward 159.85, eps 0.14
# Episode 199, average total reward 151.81, eps 0.13
# Episode 200, average total reward 138.44, eps 0.13
# Episode 201, average total reward 142.47, eps 0.13
# Episode 202, average total reward 152.06, eps 0.13
# Episode 203, average total reward 138.90, eps 0.13
# Episode 204, average total reward 153.02, eps 0.13
# Episode 205, average total reward 145.77, eps 0.13
# Episode 206, average total reward 142.30, eps 0.12
# Episode 207, average total reward 149.49, eps 0.12
# Episode 208, average total reward 144.93, eps 0.12
# Episode 209, average total reward 149.00, eps 0.12
# Episode 210, average total reward 149.25, eps 0.12
# Episode 211, average total reward 141.84, eps 0.12
# Episode 212, average total reward 153.76, eps 0.12
# Episode 213, average total reward 157.58, eps 0.12
# Episode 214, average total reward 157.18, eps 0.12
# Episode 215, average total reward 152.52, eps 0.11
# Episode 216, average total reward 151.83, eps 0.11
# Episode 217, average total reward 142.74, eps 0.11
# Episode 218, average total reward 151.58, eps 0.11
# Episode 219, average total reward 143.70, eps 0.11
# Episode 220, average total reward 150.52, eps 0.11
# Episode 221, average total reward 150.91, eps 0.11
# Episode 222, average total reward 154.61, eps 0.11
# Episode 223, average total reward 144.39, eps 0.11
# Episode 224, average total reward 144.68, eps 0.10
# Episode 225, average total reward 136.63, eps 0.10
# Episode 226, average total reward 162.63, eps 0.10
# Episode 227, average total reward 154.99, eps 0.10
# Episode 228, average total reward 141.96, eps 0.10
# Episode 229, average total reward 153.80, eps 0.10
# Episode 230, average total reward 158.35, eps 0.10
# Episode 231, average total reward 155.69, eps 0.10
# Episode 232, average total reward 161.63, eps 0.10
# Episode 233, average total reward 140.26, eps 0.10
# Episode 234, average total reward 133.71, eps 0.09
# Episode 235, average total reward 149.50, eps 0.09
# Episode 236, average total reward 153.09, eps 0.09
# Episode 237, average total reward 150.70, eps 0.09
# Episode 238, average total reward 153.91, eps 0.09
# Episode 239, average total reward 161.68, eps 0.09
# Episode 240, average total reward 149.94, eps 0.09
# Episode 241, average total reward 155.06, eps 0.09
# Episode 242, average total reward 153.45, eps 0.09
# Episode 243, average total reward 141.01, eps 0.09
# Episode 244, average total reward 158.31, eps 0.09
# Episode 245, average total reward 146.56, eps 0.08
# Episode 246, average total reward 150.87, eps 0.08
# Episode 247, average total reward 138.61, eps 0.08
# Episode 248, average total reward 161.84, eps 0.08
# Episode 249, average total reward 161.36, eps 0.08
# Episode 250, average total reward 138.48, eps 0.08
# Episode 251, average total reward 145.22, eps 0.08
# Episode 252, average total reward 145.50, eps 0.08
# Episode 253, average total reward 154.04, eps 0.08
# Episode 254, average total reward 151.13, eps 0.08
# Episode 255, average total reward 133.75, eps 0.08
# Episode 256, average total reward 150.98, eps 0.08
# Episode 257, average total reward 147.84, eps 0.07
# Episode 258, average total reward 149.69, eps 0.07
# Episode 259, average total reward 146.37, eps 0.07
# Episode 260, average total reward 142.71, eps 0.07
# Episode 261, average total reward 152.68, eps 0.07
# Episode 262, average total reward 163.10, eps 0.07
# Episode 263, average total reward 144.48, eps 0.07
# Episode 264, average total reward 164.25, eps 0.07
# Episode 265, average total reward 150.26, eps 0.07
# Episode 266, average total reward 139.36, eps 0.07
# Episode 267, average total reward 144.73, eps 0.07
# Episode 268, average total reward 147.33, eps 0.07
# Episode 269, average total reward 141.08, eps 0.07
# Episode 270, average total reward 147.20, eps 0.07
# Episode 271, average total reward 145.49, eps 0.06
# Episode 272, average total reward 168.67, eps 0.06
# Episode 273, average total reward 151.11, eps 0.06
# Episode 274, average total reward 143.52, eps 0.06
# Episode 275, average total reward 155.55, eps 0.06
# Episode 276, average total reward 158.99, eps 0.06
# Episode 277, average total reward 147.56, eps 0.06
# Episode 278, average total reward 160.11, eps 0.06
# Episode 279, average total reward 150.47, eps 0.06
# Episode 280, average total reward 152.92, eps 0.06
# Episode 281, average total reward 152.61, eps 0.06
# Episode 282, average total reward 159.01, eps 0.06
# Episode 283, average total reward 147.33, eps 0.06
# Episode 284, average total reward 149.50, eps 0.06
# Episode 285, average total reward 149.12, eps 0.06
# Episode 286, average total reward 163.61, eps 0.06
# Episode 287, average total reward 150.04, eps 0.06
# Episode 288, average total reward 158.92, eps 0.05
# Episode 289, average total reward 143.58, eps 0.05
# Episode 290, average total reward 145.07, eps 0.05
# Episode 291, average total reward 152.79, eps 0.05
# Episode 292, average total reward 156.29, eps 0.05
# Episode 293, average total reward 145.87, eps 0.05
# Episode 294, average total reward 145.06, eps 0.05
# Episode 295, average total reward 151.40, eps 0.05
# Episode 296, average total reward 152.63, eps 0.05
# Episode 297, average total reward 153.79, eps 0.05
# Episode 298, average total reward 143.97, eps 0.05
# Episode 299, average total reward 145.46, eps 0.05
# Episode 300, average total reward 147.04, eps 0.05
# Episode 301, average total reward 142.30, eps 0.05
# Episode 302, average total reward 154.29, eps 0.05
# Episode 303, average total reward 148.28, eps 0.05
# Episode 304, average total reward 151.53, eps 0.05
# Episode 305, average total reward 137.76, eps 0.05
# Episode 306, average total reward 160.01, eps 0.05
# Episode 307, average total reward 150.07, eps 0.05
# Episode 308, average total reward 149.55, eps 0.05
# Episode 309, average total reward 147.85, eps 0.05
# Episode 310, average total reward 164.61, eps 0.05
# Episode 311, average total reward 149.02, eps 0.05
# Episode 312, average total reward 153.34, eps 0.05
# Episode 313, average total reward 143.05, eps 0.05
# Episode 314, average total reward 152.76, eps 0.05
# Episode 315, average total reward 142.49, eps 0.05
# Episode 316, average total reward 145.99, eps 0.05
# Episode 317, average total reward 149.65, eps 0.05
# Episode 318, average total reward 151.81, eps 0.05
# Episode 319, average total reward 145.91, eps 0.05
# Episode 320, average total reward 151.92, eps 0.05
# Episode 321, average total reward 152.58, eps 0.05
# Episode 322, average total reward 147.65, eps 0.05
# Episode 323, average total reward 152.22, eps 0.05
# Episode 324, average total reward 148.61, eps 0.05
# Episode 325, average total reward 151.52, eps 0.05
# Episode 326, average total reward 142.07, eps 0.05
# Episode 327, average total reward 146.67, eps 0.05
# Episode 328, average total reward 152.48, eps 0.05
# Episode 329, average total reward 161.42, eps 0.05
# Episode 330, average total reward 149.88, eps 0.05
# Episode 331, average total reward 165.19, eps 0.05
# Episode 332, average total reward 149.59, eps 0.05
# Episode 333, average total reward 155.45, eps 0.05
# Episode 334, average total reward 155.17, eps 0.05
# Episode 335, average total reward 152.64, eps 0.05
# Episode 336, average total reward 140.96, eps 0.05
# Episode 337, average total reward 136.08, eps 0.05
# Episode 338, average total reward 158.66, eps 0.05
# Episode 339, average total reward 146.90, eps 0.05
# Episode 340, average total reward 146.56, eps 0.05
# Episode 341, average total reward 154.08, eps 0.05
# Episode 342, average total reward 163.35, eps 0.05
# Episode 343, average total reward 158.06, eps 0.05
# Episode 344, average total reward 146.43, eps 0.05
# Episode 345, average total reward 166.54, eps 0.05
# Episode 346, average total reward 161.83, eps 0.05
# Episode 347, average total reward 167.04, eps 0.05
# Episode 348, average total reward 151.07, eps 0.05
# Episode 349, average total reward 152.39, eps 0.05
# Episode 350, average total reward 155.17, eps 0.05
# Episode 351, average total reward 149.03, eps 0.05
# Episode 352, average total reward 153.78, eps 0.05
# Episode 353, average total reward 155.37, eps 0.05
# Episode 354, average total reward 143.05, eps 0.05
# Episode 355, average total reward 153.96, eps 0.05
# Episode 356, average total reward 159.25, eps 0.05
# Episode 357, average total reward 153.08, eps 0.05
# Episode 358, average total reward 140.68, eps 0.05
# Episode 359, average total reward 148.53, eps 0.05
# Episode 360, average total reward 163.85, eps 0.05
# Episode 361, average total reward 134.97, eps 0.05
# Episode 362, average total reward 161.41, eps 0.05
# Episode 363, average total reward 143.63, eps 0.05
# Episode 364, average total reward 145.49, eps 0.05
# Episode 365, average total reward 150.21, eps 0.05
# Episode 366, average total reward 161.77, eps 0.05
# Episode 367, average total reward 151.49, eps 0.05
# Episode 368, average total reward 145.98, eps 0.05
# Episode 369, average total reward 149.36, eps 0.05
# Episode 370, average total reward 156.08, eps 0.05
# Episode 371, average total reward 158.53, eps 0.05
# Episode 372, average total reward 147.67, eps 0.05
# Episode 373, average total reward 151.05, eps 0.05
# Episode 374, average total reward 166.56, eps 0.05
# Episode 375, average total reward 148.29, eps 0.05
# Episode 376, average total reward 161.77, eps 0.05
# Episode 377, average total reward 157.63, eps 0.05
# Episode 378, average total reward 142.82, eps 0.05
# Episode 379, average total reward 155.30, eps 0.05
# Episode 380, average total reward 151.30, eps 0.05
# Episode 381, average total reward 140.55, eps 0.05
# Episode 382, average total reward 137.08, eps 0.05
# Episode 383, average total reward 150.22, eps 0.05
# Episode 384, average total reward 143.89, eps 0.05
# Episode 385, average total reward 152.82, eps 0.05
# Episode 386, average total reward 151.74, eps 0.05
# Episode 387, average total reward 155.52, eps 0.05
# Episode 388, average total reward 154.36, eps 0.05
# Episode 389, average total reward 151.01, eps 0.05
# Episode 390, average total reward 148.11, eps 0.05
# Episode 391, average total reward 159.81, eps 0.05
# Episode 392, average total reward 145.63, eps 0.05
# Episode 393, average total reward 164.99, eps 0.05
# Episode 394, average total reward 143.14, eps 0.05
# Episode 395, average total reward 137.56, eps 0.05
# Episode 396, average total reward 143.22, eps 0.05
# Episode 397, average total reward 151.01, eps 0.05
# Episode 398, average total reward 140.21, eps 0.05
# Episode 399, average total reward 143.55, eps 0.05
# Episode 400, average total reward 151.86, eps 0.05
# Episode 401, average total reward 145.72, eps 0.05
# Episode 402, average total reward 149.43, eps 0.05
# Episode 403, average total reward 161.71, eps 0.05
# Episode 404, average total reward 146.48, eps 0.05
# Episode 405, average total reward 147.94, eps 0.05
# Episode 406, average total reward 145.29, eps 0.05
# Episode 407, average total reward 144.07, eps 0.05
# Episode 408, average total reward 146.63, eps 0.05
# Episode 409, average total reward 156.92, eps 0.05
# Episode 410, average total reward 146.23, eps 0.05
# Episode 411, average total reward 163.17, eps 0.05
# Episode 412, average total reward 157.55, eps 0.05
# Episode 413, average total reward 146.55, eps 0.05
# Episode 414, average total reward 144.87, eps 0.05
# Episode 415, average total reward 145.47, eps 0.05
# Episode 416, average total reward 132.97, eps 0.05
# Episode 417, average total reward 137.51, eps 0.05
# Episode 418, average total reward 154.32, eps 0.05
# Episode 419, average total reward 138.65, eps 0.05
# Episode 420, average total reward 145.18, eps 0.05
# Episode 421, average total reward 142.73, eps 0.05
# Episode 422, average total reward 131.35, eps 0.05
# Episode 423, average total reward 163.63, eps 0.05
# Episode 424, average total reward 152.93, eps 0.05
# Episode 425, average total reward 145.76, eps 0.05
# Episode 426, average total reward 160.51, eps 0.05
# Episode 427, average total reward 157.97, eps 0.05
# Episode 428, average total reward 149.52, eps 0.05
# Episode 429, average total reward 150.87, eps 0.05
# Episode 430, average total reward 149.46, eps 0.05
# Episode 431, average total reward 143.94, eps 0.05
# Episode 432, average total reward 140.70, eps 0.05
# Episode 433, average total reward 156.30, eps 0.05
# Episode 434, average total reward 148.41, eps 0.05
# Episode 435, average total reward 157.38, eps 0.05
# Episode 436, average total reward 158.81, eps 0.05
# Episode 437, average total reward 141.35, eps 0.05
# Episode 438, average total reward 152.21, eps 0.05
# Episode 439, average total reward 140.23, eps 0.05
# Episode 440, average total reward 153.11, eps 0.05
# Episode 441, average total reward 147.01, eps 0.05
# Episode 442, average total reward 157.83, eps 0.05
# Episode 443, average total reward 156.16, eps 0.05
# Episode 444, average total reward 140.32, eps 0.05
# Episode 445, average total reward 154.45, eps 0.05
# Episode 446, average total reward 147.32, eps 0.05
# Episode 447, average total reward 152.78, eps 0.05
# Episode 448, average total reward 153.59, eps 0.05
# Episode 449, average total reward 150.50, eps 0.05
# Episode 450, average total reward 148.47, eps 0.05
# Episode 451, average total reward 153.13, eps 0.05
# Episode 452, average total reward 150.78, eps 0.05
# Episode 453, average total reward 151.53, eps 0.05
# Episode 454, average total reward 156.64, eps 0.05
# Episode 455, average total reward 153.50, eps 0.05
# Episode 456, average total reward 140.83, eps 0.05
# Episode 457, average total reward 165.00, eps 0.05
# Episode 458, average total reward 141.46, eps 0.05
# Episode 459, average total reward 157.53, eps 0.05
# Episode 460, average total reward 160.27, eps 0.05
# Episode 461, average total reward 141.58, eps 0.05
# Episode 462, average total reward 158.18, eps 0.05
# Episode 463, average total reward 143.52, eps 0.05
# Episode 464, average total reward 149.20, eps 0.05
# Episode 465, average total reward 158.57, eps 0.05
# Episode 466, average total reward 152.56, eps 0.05
# Episode 467, average total reward 159.80, eps 0.05
# Episode 468, average total reward 157.44, eps 0.05
# Episode 469, average total reward 162.55, eps 0.05
# Episode 470, average total reward 144.36, eps 0.05
# Episode 471, average total reward 161.97, eps 0.05
# Episode 472, average total reward 145.92, eps 0.05
# Episode 473, average total reward 151.04, eps 0.05
# Episode 474, average total reward 165.14, eps 0.05
# Episode 475, average total reward 170.83, eps 0.05
# Episode 476, average total reward 153.02, eps 0.05
# Episode 477, average total reward 145.87, eps 0.05
# Episode 478, average total reward 151.10, eps 0.05
# Episode 479, average total reward 152.85, eps 0.05
# Episode 480, average total reward 140.40, eps 0.05
# Episode 481, average total reward 149.96, eps 0.05
# Episode 482, average total reward 153.38, eps 0.05
# Episode 483, average total reward 160.50, eps 0.05
# Episode 484, average total reward 147.05, eps 0.05
# Episode 485, average total reward 144.46, eps 0.05
# Episode 486, average total reward 144.20, eps 0.05
# Episode 487, average total reward 146.24, eps 0.05
# Episode 488, average total reward 154.89, eps 0.05
# Episode 489, average total reward 148.13, eps 0.05
# Episode 490, average total reward 143.07, eps 0.05
# Episode 491, average total reward 152.13, eps 0.05
# Episode 492, average total reward 148.17, eps 0.05
# Episode 493, average total reward 143.83, eps 0.05
# Episode 494, average total reward 159.94, eps 0.05
# Episode 495, average total reward 152.84, eps 0.05
# Episode 496, average total reward 149.25, eps 0.05
# Episode 497, average total reward 140.06, eps 0.05
# Episode 498, average total reward 144.61, eps 0.05
# Episode 499, average total reward 145.39, eps 0.05
# Episode 500, average total reward 155.68, eps 0.05
# Episode 501, average total reward 148.14, eps 0.05
# Episode 502, average total reward 156.40, eps 0.05
# Episode 503, average total reward 160.78, eps 0.05
# Episode 504, average total reward 138.10, eps 0.05
# Episode 505, average total reward 155.06, eps 0.05
# Episode 506, average total reward 152.53, eps 0.05
# Episode 507, average total reward 139.77, eps 0.05
# Episode 508, average total reward 151.90, eps 0.05
# Episode 509, average total reward 152.09, eps 0.05
# Episode 510, average total reward 161.59, eps 0.05
# Episode 511, average total reward 154.12, eps 0.05
# Episode 512, average total reward 156.67, eps 0.05
# Episode 513, average total reward 153.43, eps 0.05
# Episode 514, average total reward 140.67, eps 0.05
# Episode 515, average total reward 153.15, eps 0.05
# Episode 516, average total reward 149.04, eps 0.05
# Episode 517, average total reward 156.47, eps 0.05
# Episode 518, average total reward 142.55, eps 0.05
# Episode 519, average total reward 157.14, eps 0.05
# Episode 520, average total reward 150.56, eps 0.05
# Episode 521, average total reward 141.27, eps 0.05
# Episode 522, average total reward 147.87, eps 0.05
# Episode 523, average total reward 154.07, eps 0.05
# Episode 524, average total reward 151.14, eps 0.05
# Episode 525, average total reward 152.98, eps 0.05
# Episode 526, average total reward 158.28, eps 0.05
# Episode 527, average total reward 145.71, eps 0.05
# Episode 528, average total reward 169.54, eps 0.05
# Episode 529, average total reward 145.52, eps 0.05
# Episode 530, average total reward 165.57, eps 0.05
# Episode 531, average total reward 153.09, eps 0.05
# Episode 532, average total reward 161.30, eps 0.05
# Episode 533, average total reward 158.85, eps 0.05
# Episode 534, average total reward 152.33, eps 0.05
# Episode 535, average total reward 145.55, eps 0.05
# Episode 536, average total reward 135.95, eps 0.05
# Episode 537, average total reward 155.72, eps 0.05
# Episode 538, average total reward 150.12, eps 0.05
# Episode 539, average total reward 156.43, eps 0.05
# Episode 540, average total reward 156.54, eps 0.05
# Episode 541, average total reward 149.51, eps 0.05
# Episode 542, average total reward 156.13, eps 0.05
# Episode 543, average total reward 147.36, eps 0.05
# Episode 544, average total reward 149.44, eps 0.05
# Episode 545, average total reward 156.75, eps 0.05
# Episode 546, average total reward 145.50, eps 0.05
# Episode 547, average total reward 149.48, eps 0.05
# Episode 548, average total reward 153.89, eps 0.05
# Episode 549, average total reward 144.00, eps 0.05
# Episode 550, average total reward 156.58, eps 0.05
# Episode 551, average total reward 147.80, eps 0.05
# Episode 552, average total reward 149.65, eps 0.05
# Episode 553, average total reward 152.43, eps 0.05
# Episode 554, average total reward 153.96, eps 0.05
# Episode 555, average total reward 169.25, eps 0.05
# Episode 556, average total reward 133.85, eps 0.05
# Episode 557, average total reward 160.00, eps 0.05
# Episode 558, average total reward 153.56, eps 0.05
# Episode 559, average total reward 149.52, eps 0.05
# Episode 560, average total reward 145.66, eps 0.05
# Episode 561, average total reward 142.57, eps 0.05
# Episode 562, average total reward 146.43, eps 0.05
# Episode 563, average total reward 138.16, eps 0.05
# Episode 564, average total reward 156.78, eps 0.05
# Episode 565, average total reward 150.40, eps 0.05
# Episode 566, average total reward 150.78, eps 0.05
# Episode 567, average total reward 137.40, eps 0.05
# Episode 568, average total reward 143.97, eps 0.05
# Episode 569, average total reward 147.32, eps 0.05
# Episode 570, average total reward 140.68, eps 0.05
# Episode 571, average total reward 161.31, eps 0.05
# Episode 572, average total reward 136.47, eps 0.05
# Episode 573, average total reward 138.49, eps 0.05
# Episode 574, average total reward 158.26, eps 0.05
# Episode 575, average total reward 143.65, eps 0.05
# Episode 576, average total reward 151.35, eps 0.05
# Episode 577, average total reward 140.35, eps 0.05
# Episode 578, average total reward 148.90, eps 0.05
# Episode 579, average total reward 140.44, eps 0.05
# Episode 580, average total reward 162.13, eps 0.05
# Episode 581, average total reward 128.22, eps 0.05
# Episode 582, average total reward 131.59, eps 0.05
# Episode 583, average total reward 145.65, eps 0.05
# Episode 584, average total reward 151.86, eps 0.05
# Episode 585, average total reward 146.94, eps 0.05
# Episode 586, average total reward 155.16, eps 0.05
# Episode 587, average total reward 147.62, eps 0.05
# Episode 588, average total reward 154.43, eps 0.05
# Episode 589, average total reward 155.32, eps 0.05
# Episode 590, average total reward 150.02, eps 0.05
# Episode 591, average total reward 161.44, eps 0.05
# Episode 592, average total reward 163.60, eps 0.05
# Episode 593, average total reward 152.32, eps 0.05
# Episode 594, average total reward 151.94, eps 0.05
# Episode 595, average total reward 163.82, eps 0.05
# Episode 596, average total reward 140.73, eps 0.05
# Episode 597, average total reward 142.03, eps 0.05
# Episode 598, average total reward 145.86, eps 0.05
# Episode 599, average total reward 150.99, eps 0.05
# Episode 600, average total reward 163.71, eps 0.05
# Episode 601, average total reward 147.09, eps 0.05
# Episode 602, average total reward 151.85, eps 0.05
# Episode 603, average total reward 156.14, eps 0.05
# Episode 604, average total reward 164.33, eps 0.05
# Episode 605, average total reward 154.39, eps 0.05
# Episode 606, average total reward 154.95, eps 0.05
# Episode 607, average total reward 126.90, eps 0.05
# Episode 608, average total reward 143.39, eps 0.05
# Episode 609, average total reward 157.75, eps 0.05
# Episode 610, average total reward 164.68, eps 0.05
# Episode 611, average total reward 160.76, eps 0.05
# Episode 612, average total reward 139.97, eps 0.05
# Episode 613, average total reward 161.02, eps 0.05
# Episode 614, average total reward 153.36, eps 0.05
# Episode 615, average total reward 139.95, eps 0.05
# Episode 616, average total reward 140.81, eps 0.05
# Episode 617, average total reward 149.60, eps 0.05
# Episode 618, average total reward 165.26, eps 0.05
# Episode 619, average total reward 168.88, eps 0.05
# Episode 620, average total reward 161.86, eps 0.05
# Episode 621, average total reward 144.19, eps 0.05
# Episode 622, average total reward 162.89, eps 0.05
# Episode 623, average total reward 144.94, eps 0.05
# Episode 624, average total reward 166.54, eps 0.05
# Episode 625, average total reward 147.98, eps 0.05
# Episode 626, average total reward 145.15, eps 0.05
# Episode 627, average total reward 154.82, eps 0.05
# Episode 628, average total reward 152.34, eps 0.05
# Episode 629, average total reward 161.08, eps 0.05
# Episode 630, average total reward 149.89, eps 0.05
# Episode 631, average total reward 160.79, eps 0.05
# Episode 632, average total reward 154.93, eps 0.05
# Episode 633, average total reward 157.27, eps 0.05
# Episode 634, average total reward 157.83, eps 0.05
# Episode 635, average total reward 173.16, eps 0.05
# Episode 636, average total reward 150.35, eps 0.05
# Episode 637, average total reward 140.87, eps 0.05
# Episode 638, average total reward 160.39, eps 0.05
# Episode 639, average total reward 156.12, eps 0.05
# Episode 640, average total reward 142.59, eps 0.05
# Episode 641, average total reward 168.76, eps 0.05
# Episode 642, average total reward 143.98, eps 0.05
# Episode 643, average total reward 152.01, eps 0.05
# Episode 644, average total reward 149.07, eps 0.05
# Episode 645, average total reward 161.30, eps 0.05
# Episode 646, average total reward 139.89, eps 0.05
# Episode 647, average total reward 147.46, eps 0.05
# Episode 648, average total reward 152.04, eps 0.05
# Episode 649, average total reward 155.03, eps 0.05
# Episode 650, average total reward 142.81, eps 0.05
# Episode 651, average total reward 139.83, eps 0.05
# Episode 652, average total reward 141.38, eps 0.05
# Episode 653, average total reward 150.33, eps 0.05
# Episode 654, average total reward 160.03, eps 0.05
# Episode 655, average total reward 160.43, eps 0.05
# Episode 656, average total reward 149.82, eps 0.05
# Episode 657, average total reward 142.88, eps 0.05
# Episode 658, average total reward 151.80, eps 0.05
# Episode 659, average total reward 157.22, eps 0.05
# Episode 660, average total reward 154.57, eps 0.05
# Episode 661, average total reward 162.87, eps 0.05
# Episode 662, average total reward 155.92, eps 0.05
# Episode 663, average total reward 143.53, eps 0.05
# Episode 664, average total reward 148.91, eps 0.05
# Episode 665, average total reward 143.14, eps 0.05
# Episode 666, average total reward 147.36, eps 0.05
# Episode 667, average total reward 160.85, eps 0.05
# Episode 668, average total reward 141.33, eps 0.05
# Episode 669, average total reward 160.73, eps 0.05
# Episode 670, average total reward 146.60, eps 0.05
# Episode 671, average total reward 150.02, eps 0.05
# Episode 672, average total reward 166.67, eps 0.05
# Episode 673, average total reward 146.17, eps 0.05
# Episode 674, average total reward 149.84, eps 0.05
# Episode 675, average total reward 154.46, eps 0.05
# Episode 676, average total reward 155.10, eps 0.05
# Episode 677, average total reward 155.59, eps 0.05
# Episode 678, average total reward 146.64, eps 0.05
# Episode 679, average total reward 144.95, eps 0.05
# Episode 680, average total reward 148.75, eps 0.05
# Episode 681, average total reward 137.00, eps 0.05
# Episode 682, average total reward 152.40, eps 0.05
# Episode 683, average total reward 141.01, eps 0.05
# Episode 684, average total reward 158.87, eps 0.05
# Episode 685, average total reward 152.10, eps 0.05
# Episode 686, average total reward 156.63, eps 0.05
# Episode 687, average total reward 147.70, eps 0.05
# Episode 688, average total reward 141.75, eps 0.05
# Episode 689, average total reward 130.28, eps 0.05
# Episode 690, average total reward 155.20, eps 0.05
# Episode 691, average total reward 150.13, eps 0.05
# Episode 692, average total reward 143.97, eps 0.05
# Episode 693, average total reward 166.42, eps 0.05
# Episode 694, average total reward 159.40, eps 0.05
# Episode 695, average total reward 145.51, eps 0.05
# Episode 696, average total reward 151.10, eps 0.05
# Episode 697, average total reward 136.12, eps 0.05
# Episode 698, average total reward 139.94, eps 0.05
# Episode 699, average total reward 161.22, eps 0.05
# Episode 700, average total reward 147.64, eps 0.05
# Episode 701, average total reward 148.22, eps 0.05
# Episode 702, average total reward 147.26, eps 0.05
# Episode 703, average total reward 140.80, eps 0.05
# Episode 704, average total reward 152.73, eps 0.05
# Episode 705, average total reward 153.02, eps 0.05
# Episode 706, average total reward 154.48, eps 0.05
# Episode 707, average total reward 158.98, eps 0.05
# Episode 708, average total reward 155.01, eps 0.05
# Episode 709, average total reward 142.75, eps 0.05
# Episode 710, average total reward 165.21, eps 0.05
# Episode 711, average total reward 147.24, eps 0.05
# Episode 712, average total reward 148.29, eps 0.05
# Episode 713, average total reward 149.50, eps 0.05
# Episode 714, average total reward 146.95, eps 0.05
# Episode 715, average total reward 138.83, eps 0.05
# Episode 716, average total reward 157.01, eps 0.05
# Episode 717, average total reward 143.78, eps 0.05
# Episode 718, average total reward 156.99, eps 0.05
# Episode 719, average total reward 144.98, eps 0.05
# Episode 720, average total reward 163.32, eps 0.05
# Episode 721, average total reward 155.92, eps 0.05
# Episode 722, average total reward 140.00, eps 0.05
# Episode 723, average total reward 159.32, eps 0.05
# Episode 724, average total reward 138.64, eps 0.05
# Episode 725, average total reward 146.80, eps 0.05
# Episode 726, average total reward 154.59, eps 0.05
# Episode 727, average total reward 151.94, eps 0.05
# Episode 728, average total reward 155.66, eps 0.05
# Episode 729, average total reward 148.95, eps 0.05
# Episode 730, average total reward 152.84, eps 0.05
# Episode 731, average total reward 147.77, eps 0.05
# Episode 732, average total reward 168.01, eps 0.05
# Episode 733, average total reward 155.05, eps 0.05
# Episode 734, average total reward 150.42, eps 0.05
# Episode 735, average total reward 154.30, eps 0.05
# Episode 736, average total reward 162.73, eps 0.05
# Episode 737, average total reward 154.03, eps 0.05
# Episode 738, average total reward 134.55, eps 0.05
# Episode 739, average total reward 164.62, eps 0.05
# Episode 740, average total reward 152.76, eps 0.05
# Episode 741, average total reward 147.50, eps 0.05
# Episode 742, average total reward 146.92, eps 0.05
# Episode 743, average total reward 144.20, eps 0.05
# Episode 744, average total reward 161.23, eps 0.05
# Episode 745, average total reward 147.93, eps 0.05
# Episode 746, average total reward 158.22, eps 0.05
# Episode 747, average total reward 163.34, eps 0.05
# Episode 748, average total reward 156.48, eps 0.05
# Episode 749, average total reward 153.23, eps 0.05
# Episode 750, average total reward 157.65, eps 0.05
# Episode 751, average total reward 163.48, eps 0.05
# Episode 752, average total reward 134.60, eps 0.05
# Episode 753, average total reward 152.29, eps 0.05
# Episode 754, average total reward 144.41, eps 0.05
# Episode 755, average total reward 153.53, eps 0.05
# Episode 756, average total reward 156.74, eps 0.05
# Episode 757, average total reward 139.18, eps 0.05
# Episode 758, average total reward 168.54, eps 0.05
# Episode 759, average total reward 156.57, eps 0.05
# Episode 760, average total reward 154.06, eps 0.05
# Episode 761, average total reward 147.32, eps 0.05
# Episode 762, average total reward 145.09, eps 0.05
# Episode 763, average total reward 160.38, eps 0.05
# Episode 764, average total reward 147.97, eps 0.05
# Episode 765, average total reward 158.64, eps 0.05
# Episode 766, average total reward 158.76, eps 0.05
# Episode 767, average total reward 159.39, eps 0.05
# Episode 768, average total reward 155.50, eps 0.05
# Episode 769, average total reward 158.57, eps 0.05
# Episode 770, average total reward 163.71, eps 0.05
# Episode 771, average total reward 147.14, eps 0.05
# Episode 772, average total reward 150.77, eps 0.05
# Episode 773, average total reward 143.79, eps 0.05
# Episode 774, average total reward 153.60, eps 0.05
# Episode 775, average total reward 157.80, eps 0.05
# Episode 776, average total reward 148.31, eps 0.05
# Episode 777, average total reward 155.41, eps 0.05
# Episode 778, average total reward 164.47, eps 0.05
# Episode 779, average total reward 153.63, eps 0.05
# Episode 780, average total reward 138.66, eps 0.05
# Episode 781, average total reward 143.15, eps 0.05
# Episode 782, average total reward 144.83, eps 0.05
# Episode 783, average total reward 136.00, eps 0.05
# Episode 784, average total reward 158.60, eps 0.05
# Episode 785, average total reward 152.90, eps 0.05
# Episode 786, average total reward 149.15, eps 0.05
# Episode 787, average total reward 148.34, eps 0.05
# Episode 788, average total reward 155.61, eps 0.05
# Episode 789, average total reward 144.38, eps 0.05
# Episode 790, average total reward 147.94, eps 0.05
# Episode 791, average total reward 151.69, eps 0.05
# Episode 792, average total reward 143.69, eps 0.05
# Episode 793, average total reward 166.51, eps 0.05
# Episode 794, average total reward 148.53, eps 0.05
# Episode 795, average total reward 147.31, eps 0.05
# Episode 796, average total reward 165.41, eps 0.05
# Episode 797, average total reward 155.30, eps 0.05
# Episode 798, average total reward 140.50, eps 0.05
# Episode 799, average total reward 138.20, eps 0.05
# Episode 800, average total reward 148.12, eps 0.05
# Episode 801, average total reward 160.83, eps 0.05
# Episode 802, average total reward 149.73, eps 0.05
# Episode 803, average total reward 156.57, eps 0.05
# Episode 804, average total reward 147.97, eps 0.05
# Episode 805, average total reward 152.58, eps 0.05
# Episode 806, average total reward 152.68, eps 0.05
# Episode 807, average total reward 146.54, eps 0.05
# Episode 808, average total reward 153.58, eps 0.05
# Episode 809, average total reward 147.86, eps 0.05
# Episode 810, average total reward 145.96, eps 0.05
# Episode 811, average total reward 165.41, eps 0.05
# Episode 812, average total reward 160.02, eps 0.05
# Episode 813, average total reward 142.50, eps 0.05
# Episode 814, average total reward 154.20, eps 0.05
# Episode 815, average total reward 164.54, eps 0.05
# Episode 816, average total reward 149.53, eps 0.05
# Episode 817, average total reward 132.28, eps 0.05
# Episode 818, average total reward 145.25, eps 0.05
# Episode 819, average total reward 146.81, eps 0.05
# Episode 820, average total reward 146.33, eps 0.05
# Episode 821, average total reward 151.75, eps 0.05
# Episode 822, average total reward 143.72, eps 0.05
# Episode 823, average total reward 158.29, eps 0.05
# Episode 824, average total reward 147.39, eps 0.05
# Episode 825, average total reward 146.76, eps 0.05
# Episode 826, average total reward 150.59, eps 0.05
# Episode 827, average total reward 146.49, eps 0.05
# Episode 828, average total reward 145.58, eps 0.05
# Episode 829, average total reward 146.17, eps 0.05
# Episode 830, average total reward 142.04, eps 0.05
# Episode 831, average total reward 153.29, eps 0.05
# Episode 832, average total reward 145.88, eps 0.05
# Episode 833, average total reward 159.05, eps 0.05
# Episode 834, average total reward 162.55, eps 0.05
# Episode 835, average total reward 136.80, eps 0.05
# Episode 836, average total reward 151.03, eps 0.05
# Episode 837, average total reward 151.63, eps 0.05
# Episode 838, average total reward 149.10, eps 0.05
# Episode 839, average total reward 171.93, eps 0.05
# Episode 840, average total reward 153.48, eps 0.05
# Episode 841, average total reward 145.43, eps 0.05
# Episode 842, average total reward 141.78, eps 0.05
# Episode 843, average total reward 144.93, eps 0.05
# Episode 844, average total reward 165.67, eps 0.05
# Episode 845, average total reward 171.30, eps 0.05
# Episode 846, average total reward 158.90, eps 0.05
# Episode 847, average total reward 144.23, eps 0.05
# Episode 848, average total reward 156.24, eps 0.05
# Episode 849, average total reward 150.79, eps 0.05
# Episode 850, average total reward 151.62, eps 0.05
# Episode 851, average total reward 138.33, eps 0.05
# Episode 852, average total reward 152.32, eps 0.05
# Episode 853, average total reward 156.26, eps 0.05
# Episode 854, average total reward 152.22, eps 0.05
# Episode 855, average total reward 146.50, eps 0.05
# Episode 856, average total reward 153.11, eps 0.05
# Episode 857, average total reward 149.99, eps 0.05
# Episode 858, average total reward 151.07, eps 0.05
# Episode 859, average total reward 142.74, eps 0.05
# Episode 860, average total reward 147.86, eps 0.05
# Episode 861, average total reward 154.36, eps 0.05
# Episode 862, average total reward 157.89, eps 0.05
# Episode 863, average total reward 144.96, eps 0.05
# Episode 864, average total reward 154.64, eps 0.05
# Episode 865, average total reward 143.23, eps 0.05
# Episode 866, average total reward 150.05, eps 0.05
# Episode 867, average total reward 140.32, eps 0.05
# Episode 868, average total reward 152.73, eps 0.05
# Episode 869, average total reward 152.58, eps 0.05
# Episode 870, average total reward 136.00, eps 0.05
# Episode 871, average total reward 157.06, eps 0.05
# Episode 872, average total reward 137.55, eps 0.05
# Episode 873, average total reward 165.02, eps 0.05
# Episode 874, average total reward 147.46, eps 0.05
# Episode 875, average total reward 140.58, eps 0.05
# Episode 876, average total reward 151.69, eps 0.05
# Episode 877, average total reward 140.09, eps 0.05
# Episode 878, average total reward 178.41, eps 0.05
# Episode 879, average total reward 150.18, eps 0.05
# Episode 880, average total reward 154.79, eps 0.05
# Episode 881, average total reward 154.19, eps 0.05
# Episode 882, average total reward 156.57, eps 0.05
# Episode 883, average total reward 153.37, eps 0.05
# Episode 884, average total reward 147.32, eps 0.05
# Episode 885, average total reward 154.61, eps 0.05
# Episode 886, average total reward 158.54, eps 0.05
# Episode 887, average total reward 133.12, eps 0.05
# Episode 888, average total reward 129.55, eps 0.05
# Episode 889, average total reward 140.17, eps 0.05
# Episode 890, average total reward 138.64, eps 0.05
# Episode 891, average total reward 149.33, eps 0.05
# Episode 892, average total reward 163.56, eps 0.05
# Episode 893, average total reward 148.52, eps 0.05
# Episode 894, average total reward 142.89, eps 0.05
# Episode 895, average total reward 148.49, eps 0.05
# Episode 896, average total reward 139.06, eps 0.05
# Episode 897, average total reward 155.80, eps 0.05
# Episode 898, average total reward 139.40, eps 0.05
# Episode 899, average total reward 139.75, eps 0.05
# Episode 900, average total reward 142.80, eps 0.05
# Episode 901, average total reward 146.13, eps 0.05
# Episode 902, average total reward 161.90, eps 0.05
# Episode 903, average total reward 148.94, eps 0.05
# Episode 904, average total reward 166.77, eps 0.05
# Episode 905, average total reward 162.38, eps 0.05
# Episode 906, average total reward 151.43, eps 0.05
# Episode 907, average total reward 161.91, eps 0.05
# Episode 908, average total reward 153.11, eps 0.05
# Episode 909, average total reward 139.23, eps 0.05
# Episode 910, average total reward 144.99, eps 0.05
# Episode 911, average total reward 155.88, eps 0.05
# Episode 912, average total reward 167.04, eps 0.05
# Episode 913, average total reward 144.72, eps 0.05
# Episode 914, average total reward 145.84, eps 0.05
# Episode 915, average total reward 161.13, eps 0.05
# Episode 916, average total reward 151.66, eps 0.05
# Episode 917, average total reward 146.14, eps 0.05
# Episode 918, average total reward 154.88, eps 0.05
# Episode 919, average total reward 147.21, eps 0.05
# Episode 920, average total reward 138.12, eps 0.05
# Episode 921, average total reward 138.46, eps 0.05
# Episode 922, average total reward 142.80, eps 0.05
# Episode 923, average total reward 149.50, eps 0.05
# Episode 924, average total reward 155.20, eps 0.05
# Episode 925, average total reward 153.12, eps 0.05
# Episode 926, average total reward 152.76, eps 0.05
# Episode 927, average total reward 160.21, eps 0.05
# Episode 928, average total reward 155.26, eps 0.05
# Episode 929, average total reward 156.87, eps 0.05
# Episode 930, average total reward 150.68, eps 0.05
# Episode 931, average total reward 158.39, eps 0.05
# Episode 932, average total reward 156.29, eps 0.05
# Episode 933, average total reward 147.06, eps 0.05
# Episode 934, average total reward 143.91, eps 0.05
# Episode 935, average total reward 152.83, eps 0.05
# Episode 936, average total reward 140.75, eps 0.05
# Episode 937, average total reward 154.66, eps 0.05
# Episode 938, average total reward 151.97, eps 0.05
# Episode 939, average total reward 145.02, eps 0.05
# Episode 940, average total reward 153.06, eps 0.05
# Episode 941, average total reward 145.21, eps 0.05
# Episode 942, average total reward 152.61, eps 0.05
# Episode 943, average total reward 148.54, eps 0.05
# Episode 944, average total reward 161.10, eps 0.05
# Episode 945, average total reward 137.34, eps 0.05
# Episode 946, average total reward 149.44, eps 0.05
# Episode 947, average total reward 141.21, eps 0.05
# Episode 948, average total reward 147.37, eps 0.05
# Episode 949, average total reward 145.08, eps 0.05
# Episode 950, average total reward 144.81, eps 0.05
# Episode 951, average total reward 138.78, eps 0.05
# Episode 952, average total reward 154.89, eps 0.05
# Episode 953, average total reward 158.78, eps 0.05
# Episode 954, average total reward 151.04, eps 0.05
# Episode 955, average total reward 148.92, eps 0.05
# Episode 956, average total reward 147.88, eps 0.05
# Episode 957, average total reward 153.50, eps 0.05
# Episode 958, average total reward 149.43, eps 0.05
# Episode 959, average total reward 150.11, eps 0.05
# Episode 960, average total reward 152.62, eps 0.05
# Episode 961, average total reward 147.30, eps 0.05
# Episode 962, average total reward 152.39, eps 0.05
# Episode 963, average total reward 156.72, eps 0.05
# Episode 964, average total reward 161.00, eps 0.05
# Episode 965, average total reward 135.62, eps 0.05
# Episode 966, average total reward 148.10, eps 0.05
# Episode 967, average total reward 156.52, eps 0.05
# Episode 968, average total reward 148.06, eps 0.05
# Episode 969, average total reward 145.04, eps 0.05
# Episode 970, average total reward 149.39, eps 0.05
# Episode 971, average total reward 154.77, eps 0.05
# Episode 972, average total reward 139.47, eps 0.05
# Episode 973, average total reward 148.50, eps 0.05
# Episode 974, average total reward 147.86, eps 0.05
# Episode 975, average total reward 158.63, eps 0.05
# Episode 976, average total reward 148.41, eps 0.05
# Episode 977, average total reward 158.34, eps 0.05
# Episode 978, average total reward 152.30, eps 0.05
# Episode 979, average total reward 145.09, eps 0.05
# Episode 980, average total reward 156.23, eps 0.05
# Episode 981, average total reward 153.04, eps 0.05
# Episode 982, average total reward 152.74, eps 0.05
# Episode 983, average total reward 154.06, eps 0.05
# Episode 984, average total reward 155.74, eps 0.05
# Episode 985, average total reward 157.14, eps 0.05
# Episode 986, average total reward 156.98, eps 0.05
# Episode 987, average total reward 149.93, eps 0.05
# Episode 988, average total reward 147.58, eps 0.05
# Episode 989, average total reward 162.06, eps 0.05
# Episode 990, average total reward 147.09, eps 0.05
# Episode 991, average total reward 159.65, eps 0.05
# Episode 992, average total reward 159.31, eps 0.05
# Episode 993, average total reward 144.11, eps 0.05
# Episode 994, average total reward 150.57, eps 0.05
# Episode 995, average total reward 146.71, eps 0.05
# Episode 996, average total reward 149.50, eps 0.05
# Episode 997, average total reward 154.84, eps 0.05
# Episode 998, average total reward 147.32, eps 0.05
# Episode 999, average total reward 147.01, eps 0.05

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import animation
from IPython.display import display, clear_output

def visualize_swarm(agent, env, steps=50, save=False, interval=10):
    """
    Visualize swarm movement in 3D and optionally save 4 views as .gif.
    - save=False → real-time live animation (in Jupyter)
    - save=True  → export 4 gifs: normal, xy, xz, yz
    """

    obs = env.reset()
    positions_history = [env.positions.copy()]

    for _ in range(steps):
        actions = [agent.select_action(o) for o in obs]
        obs, _, done, _ = env.step(actions, error_tolerance=0.25)
        positions_history.append(env.positions.copy())
        if done:
            break

    positions_history = np.array(positions_history)  # shape: [T, n_agents, 3]
    n_steps, n_agents, _ = positions_history.shape

    # Normalize goal shape
    goals = np.atleast_2d(env.goal)
    if goals.shape[0] == 1:
        goals = np.repeat(goals, n_agents, axis=0)

    # ----------------------------
    # Helper to make and save GIFs
    # ----------------------------
    def make_animation(view_name, elev, azim):
        fig = plt.figure(figsize=(6, 6))
        ax = fig.add_subplot(111, projection='3d')
        ax.set_xlim(0, env.space_size)
        ax.set_ylim(0, env.space_size)
        ax.set_zlim(0, env.space_size)
        ax.set_xlabel("X-axis")
        ax.set_ylabel("Y-axis")
        ax.set_zlabel("Z-axis")
        ax.set_title(f"3D Swarm Movement ({view_name})")

        scat = ax.scatter([], [], [], c='blue', s=50, label='Agents')
        ax.scatter(goals[:,0], goals[:,1], goals[:,2],
                   c='red', s=100, marker='*', label='Goals')

        lines = [ax.plot([], [], [], 'gray', linestyle='--', linewidth=1)[0]
                 for _ in range(n_agents)]

        ax.view_init(elev=elev, azim=azim)
        ax.legend()

        def init():
            scat._offsets3d = ([], [], [])
            for line in lines:
                line.set_data([], [])
                line.set_3d_properties([])
            return [scat, *lines]

        def update(frame):
            pos = positions_history[frame]
            scat._offsets3d = (pos[:,0], pos[:,1], pos[:,2])
            for i, line in enumerate(lines):
                x = [pos[i, 0], goals[i, 0]]
                y = [pos[i, 1], goals[i, 1]]
                z = [pos[i, 2], goals[i, 2]]
                line.set_data(x, y)
                line.set_3d_properties(z)
            ax.set_title(f"3D Swarm Movement ({view_name}) - Step {frame}/{n_steps}")
            return [scat, *lines]

        ani = animation.FuncAnimation(
            fig, update, frames=n_steps, init_func=init,
            interval=interval, blit=False
        )

        if save:
            filename = f"swarm_simulation_{view_name.lower()}.gif"
            ani.save(filename, writer='pillow')
            print(f"✅ Saved {filename}")
        else:
            plt.show()

        plt.close(fig)


    # ------------------------------------------------
    # A) SAVE FOUR VIEWS AS GIFS
    # ------------------------------------------------
    if save:
        make_animation("normal", elev=30, azim=45)
        make_animation("xy", elev=90, azim=-90)
        make_animation("xz", elev=0, azim=-90)
        make_animation("yz", elev=0, azim=0)
        return

    # ------------------------------------------------
    # B) LIVE DISPLAY (REAL-TIME UPDATE in Jupyter)
    # ------------------------------------------------
    plt.ion()  # Turn on interactive mode
    fig = plt.figure(figsize=(6, 6))
    ax = fig.add_subplot(111, projection='3d')
    ax.set_xlim(0, env.space_size)
    ax.set_ylim(0, env.space_size)
    ax.set_zlim(0, env.space_size)
    ax.set_title("3D Swarm Movement (Live)")
    scat = ax.scatter([], [], [], c='blue', s=50, label='Agents')
    ax.scatter(goals[:,0], goals[:,1], goals[:,2],
               c='red', s=100, marker='*', label='Goals')
    lines = [ax.plot([], [], [], 'gray', linestyle='--', linewidth=1)[0]
             for _ in range(n_agents)]
    ax.legend()

    for frame in range(n_steps):
        pos = positions_history[frame]
        scat._offsets3d = (pos[:,0], pos[:,1], pos[:,2])
        for i, line in enumerate(lines):
            x = [pos[i, 0], goals[i, 0]]
            y = [pos[i, 1], goals[i, 1]]
            z = [pos[i, 2], goals[i, 2]]
            line.set_data(x, y)
            line.set_3d_properties(z)
        ax.set_title(f"3D Swarm Movement (Live) - Step {frame}/{n_steps}")
        display(fig)
        clear_output(wait=True)
        plt.pause(interval / 1000.0)

    plt.ioff()
    plt.show()

# %%
  visualize_swarm(agent, env, steps=500, save=True)
# Out:
# ✅ Saved swarm_simulation_normal.gif
# ✅ Saved swarm_simulation_xy.gif
# ✅ Saved swarm_simulation_xz.gif
# ✅ Saved swarm_simulation_yz.gif
